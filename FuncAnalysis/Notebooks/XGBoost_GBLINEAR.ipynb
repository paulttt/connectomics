# %%
import pandas as pd 
import numpy as np
import xgboost as xgb
from sklearn import metrics
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import pickle
import json
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %%
root = '../'
X_train = pd.read_csv(root + 'data/Haleh/feature_datasets/X_train.csv')
X_train_full = pd.read_csv(root + 'data/Haleh/feature_datasets/X_train_dec.csv')
X_test = pd.read_csv(root + 'data/Haleh/feature_datasets/X_test.csv')
X_test_full = pd.read_csv(root + 'data/Haleh/feature_datasets/X_test_dec.csv')

y_train = np.load(root + 'data/Haleh/y_train.npy')
y_test = np.load(root + 'data/Haleh/y_test.npy')

# %%
X_train_full.head()
# Out:
#         z_0        z_1        z_2       z_3       z_4        z_5        z_6  \
# 0 -4.102828  12.117376   2.979742  6.824316  8.521718  -3.394531   3.834200
# 1 -6.215706  12.255225  22.190172 -0.212288 -5.466818 -28.439009 -11.580964
# 2 -6.349346  12.251351  22.159270 -0.396654 -5.702261 -28.601473 -11.648271
# 3 -1.180088  -9.493090  12.479339  2.376886  3.711802  -5.103728   0.372605
# 4 -1.003413 -10.825782  13.547513  2.483605  4.324685  -5.714592   0.728139
#
#          z_7       z_8        z_9  ...  0__fourier_entropy__bins_2  \
# 0  -5.100700 -0.607759   0.902113  ...                    0.079983
# 1  11.495201 -4.141428  10.182698  ...                    0.163982
# 2  11.519348 -4.056820  10.192198  ...                    0.210883
# 3  11.038977 -3.201739  -4.864267  ...                    0.110453
# 4  12.329692 -3.472347  -5.438126  ...                    0.110453
#
#    0__fourier_entropy__bins_3  0__fourier_entropy__bins_5  \
# 0                    0.079983                    0.170467
# 1                    0.247940                    0.327050
# 2                    0.275463                    0.408537
# 3                    0.155665                    0.280179
# 4                    0.159721                    0.235155
#
#    0__fourier_entropy__bins_10  0__fourier_entropy__bins_100  \
# 0                     0.280179                      0.597595
# 1                     0.488548                      0.796679
# 2                     0.482843                      0.907649
# 3                     0.452701                      0.859510
# 4                     0.412056                      0.741638
#
#    0__permutation_entropy__dimension_3__tau_1  \
# 0                                    1.203390
# 1                                    1.198716
# 2                                    1.201300
# 3                                    1.256123
# 4                                    1.240362
#
#    0__permutation_entropy__dimension_4__tau_1  \
# 0                                    1.766804
# 1                                    1.766011
# 2                                    1.770794
# 3                                    1.882432
# 4                                    1.833065
#
#    0__permutation_entropy__dimension_5__tau_1  \
# 0                                    2.354477
# 1                                    2.367617
# 2                                    2.372899
# 3                                    2.550049
# 4                                    2.450065
#
#    0__permutation_entropy__dimension_6__tau_1  \
# 0                                    2.933702
# 1                                    2.970901
# 2                                    2.981178
# 3                                    3.222475
# 4                                    3.049852
#
#    0__permutation_entropy__dimension_7__tau_1
# 0                                    3.466107
# 1                                    3.556645
# 2                                    3.582805
# 3                                    3.874065
# 4                                    3.636782
#
# [5 rows x 788 columns]

# %%
best_params = {'DEC_Feature_DS': {
    'gblinear': {'alpha': 1.1375256185723135e-08,
                 'booster': 'gblinear',
                 'feature_selector': 'shuffle',
                 'lambda': 3.6963750283518966e-08,
                 'learning_rate': 0.3182599985270911,
                 'num_boost_round': 729,
                 'objective': 'binary:logistic',
                 'scale_pos_weight': 6,
                 'updater': 'shotgun',
                 'verbosity': 0}},
               'Feature_DS': {
    'gblinear': {'alpha': 0.05663610210741058,
                 'booster': 'gblinear',
                 'feature_selector': 'shuffle',
                 'lambda': 9.25194196329593e-08,
                 'learning_rate': 0.0405063980023227,
                 'num_boost_round': 617,
                 'objective': 'binary:logistic',
                 'scale_pos_weight': 6,
                 'updater': 'shotgun',
                 'verbosity': 0}}}

# %%
space={'alpha': hp.uniform("alpha", 0, 12),
        'lambda': hp.uniform('lambda', 0,12),
        'learning_rate' : hp.uniform('learning_rate', 0.01, 0.5),
        'num_boost_round' : hp.uniform('num_boost_round', 5, 1000),
        'objective': 'binary:logistic',
        'scale_pos_weight': 1,
        'updater': 'shotgun',
        'verbosity': 0,
        'booster': 'gblinear',
        'feature_selector': 'shuffle',
        'n_estimators': 180
    }

# %%
def objective_dec(space):
    params = {
        'alpha': space['alpha'],
        'lambda': space['lambda'],
        'learning_rate' : space['learning_rate'],
        'num_boost_round' : int(space['num_boost_round']),
        'objective': space['objective'],
        'scale_pos_weight': space['scale_pos_weight'],
        'updater': space['updater'],
        'verbosity': space['verbosity'],
        'booster': space['booster'],
        'feature_selector': space['feature_selector'],
        'n_estimators': space['n_estimators']
    }
    
    n_splits = 3
    skf = StratifiedKFold(n_splits)
    
    auc = 0.0
    for train_index, eval_index in skf.split(X_train_full, y_train):
        x_train_split = X_train_full[X_train_full.index.isin(train_index)]
        x_eval_split = X_train_full[X_train_full.index.isin(eval_index)]
        y_train_split = y_train[train_index]
        y_eval_split = y_train[eval_index]
        
        clf=xgb.XGBClassifier(**params, use_label_encoder=False)

        evaluation = [(x_train_split, y_train_split), (x_eval_split, y_eval_split)]

        clf.fit(x_train_split, y_train_split,
                eval_set=evaluation, eval_metric="auc",
                early_stopping_rounds=12,verbose=False)


        pred = clf.predict_proba(x_eval_split)[:, 1]
        auc += metrics.roc_auc_score(y_eval_split, pred)
        
    auc /= n_splits
    print (f"SCORE: \t\t{auc:.3f}")
    return {'loss': -auc, 'status': STATUS_OK }

def objective(space):
    params = {
        'alpha': space['alpha'],
        'lambda': space['lambda'],
        'learning_rate' : space['learning_rate'],
        'num_boost_round' : int(space['num_boost_round']),
        'objective': space['objective'],
        'scale_pos_weight': space['scale_pos_weight'],
        'updater': space['updater'],
        'verbosity': space['verbosity'],
        'booster': space['booster'],
        'feature_selector': space['feature_selector'],
        'n_estimators': space['n_estimators']
    }
    
    n_splits = 3
    skf = StratifiedKFold(n_splits)
    auc = 0.0
    for train_index, eval_index in skf.split(X_train, y_train):
        x_train_split = X_train[X_train.index.isin(train_index)]
        x_eval_split = X_train[X_train.index.isin(eval_index)]
        y_train_split = y_train[train_index]
        y_eval_split = y_train[eval_index]
        
        clf=xgb.XGBClassifier(**params, use_label_encoder=False)
    
        evaluation = [(x_train_split, y_train_split), (x_eval_split, y_eval_split)]
    
        clf.fit(x_train_split, y_train_split,
                eval_set=evaluation, eval_metric="auc",
                early_stopping_rounds=10,verbose=False)


        pred = clf.predict_proba(x_eval_split)[:, 1]
        auc += metrics.roc_auc_score(y_eval_split, pred)
        
    auc /= n_splits

    print (f"SCORE: \t\t{auc:.3f}")
    return {'loss': -auc, 'status': STATUS_OK }

# %%
trials_standard = Trials()

best_hyperparams_standard = fmin(fn = objective,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 1000,
                        trials = trials_standard)
# Out:
# SCORE: 		0.625
# SCORE: 		0.560
# SCORE: 		0.536
# SCORE: 		0.631
# SCORE: 		0.633
# SCORE: 		0.529
# SCORE: 		0.550
# SCORE: 		0.601
# SCORE: 		0.652
# SCORE: 		0.593
# SCORE: 		0.571
# SCORE: 		0.534
# SCORE: 		0.566
# SCORE: 		0.630
# SCORE: 		0.601
# SCORE: 		0.594
# SCORE: 		0.533
# SCORE: 		0.532
# SCORE: 		0.621
# SCORE: 		0.536
# SCORE: 		0.643
# SCORE: 		0.641
# SCORE: 		0.628
# SCORE: 		0.652
# SCORE: 		0.605
# SCORE: 		0.654
# SCORE: 		0.616
# SCORE: 		0.654
# SCORE: 		0.627
# SCORE: 		0.597
# SCORE: 		0.626
# SCORE: 		0.611
# SCORE: 		0.647
# SCORE: 		0.638
# SCORE: 		0.656
# SCORE: 		0.594
# SCORE: 		0.606
# SCORE: 		0.626
# SCORE: 		0.646
# SCORE: 		0.536
# SCORE: 		0.612
# SCORE: 		0.588
# SCORE: 		0.598
# SCORE: 		0.659
# SCORE: 		0.641
# SCORE: 		0.628
# SCORE: 		0.585
# SCORE: 		0.576
# SCORE: 		0.544
# SCORE: 		0.661
# SCORE: 		0.658
# SCORE: 		0.595
# SCORE: 		0.642
# SCORE: 		0.559
# SCORE: 		0.623
# SCORE: 		0.604
# SCORE: 		0.612
# SCORE: 		0.529
# SCORE: 		0.572
# SCORE: 		0.639
# SCORE: 		0.658
# SCORE: 		0.630
# SCORE: 		0.579
# SCORE: 		0.605
# SCORE: 		0.651
# SCORE: 		0.653
# SCORE: 		0.660
# SCORE: 		0.640
# SCORE: 		0.628
# SCORE: 		0.643
# SCORE: 		0.619
# SCORE: 		0.661
# SCORE: 		0.648
# SCORE: 		0.620
# SCORE: 		0.609
# SCORE: 		0.661
# SCORE: 		0.623
# SCORE: 		0.652
# SCORE: 		0.591
# SCORE: 		0.636
# SCORE: 		0.617
# SCORE: 		0.623
# SCORE: 		0.598
# SCORE: 		0.627
# SCORE: 		0.655
# SCORE: 		0.644
# SCORE: 		0.638
# SCORE: 		0.657
# SCORE: 		0.611
# SCORE: 		0.636
# SCORE: 		0.631
# SCORE: 		0.543
# SCORE: 		0.534
# SCORE: 		0.650
# SCORE: 		0.608
# SCORE: 		0.629
# SCORE: 		0.549
# SCORE: 		0.629
# SCORE: 		0.594
# SCORE: 		0.644
# SCORE: 		0.596
# SCORE: 		0.597
# SCORE: 		0.573
# SCORE: 		0.605
# SCORE: 		0.605
# SCORE: 		0.609
# SCORE: 		0.661
# SCORE: 		0.637
# SCORE: 		0.553
# SCORE: 		0.551
# SCORE: 		0.627
# SCORE: 		0.640
# SCORE: 		0.654
# SCORE: 		0.630
# SCORE: 		0.621
# SCORE: 		0.655
# SCORE: 		0.527
# SCORE: 		0.656
# SCORE: 		0.639
# SCORE: 		0.642
# SCORE: 		0.623
# SCORE: 		0.627
# SCORE: 		0.626
# SCORE: 		0.605
# SCORE: 		0.624
# SCORE: 		0.652
# SCORE: 		0.616
# SCORE: 		0.642
# SCORE: 		0.655
# SCORE: 		0.544
# SCORE: 		0.624
# SCORE: 		0.607
# SCORE: 		0.539
# SCORE: 		0.631
# SCORE: 		0.657
# SCORE: 		0.621
# SCORE: 		0.583
# SCORE: 		0.530
# SCORE: 		0.654
# SCORE: 		0.589
# SCORE: 		0.548
# SCORE: 		0.658
# SCORE: 		0.634
# SCORE: 		0.644
# SCORE: 		0.629
# SCORE: 		0.661
# SCORE: 		0.656
# SCORE: 		0.641
# SCORE: 		0.650
# SCORE: 		0.660
# SCORE: 		0.653
# SCORE: 		0.630
# SCORE: 		0.621
# SCORE: 		0.648
# SCORE: 		0.661
# SCORE: 		0.640
# SCORE: 		0.573
# SCORE: 		0.652
# SCORE: 		0.633
# SCORE: 		0.632
# SCORE: 		0.642
# SCORE: 		0.626
# SCORE: 		0.654
# SCORE: 		0.649
# SCORE: 		0.646
# SCORE: 		0.659
# SCORE: 		0.639
# SCORE: 		0.637
# SCORE: 		0.634
# SCORE: 		0.600
# SCORE: 		0.613
# SCORE: 		0.642
# SCORE: 		0.657
# SCORE: 		0.633
# SCORE: 		0.657
# SCORE: 		0.587
# SCORE: 		0.621
# SCORE: 		0.563
# SCORE: 		0.601
# SCORE: 		0.648
# SCORE: 		0.606
# SCORE: 		0.618
# SCORE: 		0.605
# SCORE: 		0.630
# SCORE: 		0.644
# SCORE: 		0.627
# SCORE: 		0.640
# SCORE: 		0.658
# SCORE: 		0.652
# SCORE: 		0.650
# SCORE: 		0.640
# SCORE: 		0.643
# SCORE: 		0.634
# SCORE: 		0.654
# SCORE: 		0.601
# SCORE: 		0.625
# SCORE: 		0.654
# SCORE: 		0.661
# SCORE: 		0.645
# SCORE: 		0.566
# SCORE: 		0.649
# SCORE: 		0.576
# SCORE: 		0.660
# SCORE: 		0.631
# SCORE: 		0.636
# SCORE: 		0.608
# SCORE: 		0.600
# SCORE: 		0.633
# SCORE: 		0.551
# SCORE: 		0.648
# SCORE: 		0.606
# SCORE: 		0.644
# SCORE: 		0.633
# SCORE: 		0.572
# SCORE: 		0.661
# SCORE: 		0.638
# SCORE: 		0.633
# SCORE: 		0.600
# SCORE: 		0.564
# SCORE: 		0.653
# SCORE: 		0.623
# SCORE: 		0.622
# SCORE: 		0.637
# SCORE: 		0.602
# SCORE: 		0.655
# SCORE: 		0.590
# SCORE: 		0.650
# SCORE: 		0.636
# SCORE: 		0.574
# SCORE: 		0.538
# SCORE: 		0.554
# SCORE: 		0.659
# SCORE: 		0.644
# SCORE: 		0.631
# SCORE: 		0.653
# SCORE: 		0.660
# SCORE: 		0.641
# SCORE: 		0.610
# SCORE: 		0.619
# SCORE: 		0.639
# SCORE: 		0.651
# SCORE: 		0.625
# SCORE: 		0.610
# SCORE: 		0.587
# SCORE: 		0.643
# SCORE: 		0.640
# SCORE: 		0.660
# SCORE: 		0.627
# SCORE: 		0.557
# SCORE: 		0.660
# SCORE: 		0.643
# SCORE: 		0.647
# SCORE: 		0.603
# SCORE: 		0.529
# SCORE: 		0.611
# SCORE: 		0.643
# SCORE: 		0.625
# SCORE: 		0.655
# SCORE: 		0.660
# SCORE: 		0.644
# SCORE: 		0.660
# SCORE: 		0.654
# SCORE: 		0.640
# SCORE: 		0.654
# SCORE: 		0.659
# SCORE: 		0.642
# SCORE: 		0.652
# SCORE: 		0.641
# SCORE: 		0.660
# SCORE: 		0.645
# SCORE: 		0.653
# SCORE: 		0.649
# SCORE: 		0.628
# SCORE: 		0.660
# SCORE: 		0.634
# SCORE: 		0.635
# SCORE: 		0.650
# SCORE: 		0.651
# SCORE: 		0.640
# SCORE: 		0.629
# ...
# SCORE: 		0.654
# SCORE: 		0.633
# SCORE: 		0.657
# SCORE: 		0.632
# SCORE: 		0.649
# SCORE: 		0.649
# SCORE: 		0.656
# SCORE: 		0.645
# SCORE: 		0.638
# SCORE: 		0.661
# SCORE: 		0.618
# SCORE: 		0.640
# SCORE: 		0.654
# SCORE: 		0.650
# SCORE: 		0.655
# SCORE: 		0.615
# SCORE: 		0.645
# SCORE: 		0.661
# SCORE: 		0.634
# SCORE: 		0.647
# SCORE: 		0.652
# SCORE: 		0.627
# SCORE: 		0.658
# SCORE: 		0.551
# SCORE: 		0.642
# SCORE: 		0.650
# SCORE: 		0.659
# SCORE: 		0.639
# SCORE: 		0.653
# SCORE: 		0.659
# SCORE: 		0.653
# SCORE: 		0.638
# SCORE: 		0.570
# SCORE: 		0.598
# SCORE: 		0.661
# SCORE: 		0.657
# SCORE: 		0.642
# SCORE: 		0.656
# SCORE: 		0.648
# SCORE: 		0.661
# SCORE: 		0.654
# SCORE: 		0.622
# SCORE: 		0.630
# SCORE: 		0.635
# SCORE: 		0.635
# SCORE: 		0.636
# SCORE: 		0.658
# SCORE: 		0.658
# SCORE: 		0.625
# SCORE: 		0.634
# SCORE: 		0.657
# SCORE: 		0.645
# SCORE: 		0.640
# SCORE: 		0.648
# SCORE: 		0.574
# SCORE: 		0.660
# SCORE: 		0.635
# SCORE: 		0.645
# SCORE: 		0.591
# SCORE: 		0.635
# SCORE: 		0.655
# SCORE: 		0.654
# SCORE: 		0.661
# SCORE: 		0.648
# SCORE: 		0.640
# SCORE: 		0.645
# SCORE: 		0.611
# SCORE: 		0.630
# SCORE: 		0.659
# SCORE: 		0.622
# SCORE: 		0.657
# SCORE: 		0.646
# SCORE: 		0.641
# SCORE: 		0.657
# SCORE: 		0.640
# SCORE: 		0.655
# SCORE: 		0.636
# SCORE: 		0.634
# SCORE: 		0.659
# SCORE: 		0.661
# SCORE: 		0.626
# SCORE: 		0.648
# SCORE: 		0.638
# SCORE: 		0.598
# SCORE: 		0.650
# SCORE: 		0.661
# SCORE: 		0.631
# SCORE: 		0.639
# SCORE: 		0.655
# SCORE: 		0.641
# SCORE: 		0.657
# SCORE: 		0.640
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [18:39<00:00,  1.12s/trial, best loss: -0.6616551207040106]

# %%
trials_dec = Trials()

best_hyperparams_dec = fmin(fn = objective_dec,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 1000,
                        trials = trials_dec)
# Out:
# SCORE: 		0.542
# SCORE: 		0.577
# SCORE: 		0.551
# SCORE: 		0.555
# SCORE: 		0.605
# SCORE: 		0.550
# SCORE: 		0.606
# SCORE: 		0.641
# SCORE: 		0.616
# SCORE: 		0.533
# SCORE: 		0.573
# SCORE: 		0.650
# SCORE: 		0.654
# SCORE: 		0.585
# SCORE: 		0.586
# SCORE: 		0.604
# SCORE: 		0.566
# SCORE: 		0.590
# SCORE: 		0.606
# SCORE: 		0.612
# SCORE: 		0.642
# SCORE: 		0.634
# SCORE: 		0.631
# SCORE: 		0.634
# SCORE: 		0.624
# SCORE: 		0.655
# SCORE: 		0.646
# SCORE: 		0.630
# SCORE: 		0.655
# SCORE: 		0.621
# SCORE: 		0.655
# SCORE: 		0.631
# SCORE: 		0.615
# SCORE: 		0.532
# SCORE: 		0.532
# SCORE: 		0.543
# SCORE: 		0.657
# SCORE: 		0.610
# SCORE: 		0.575
# SCORE: 		0.633
# SCORE: 		0.631
# SCORE: 		0.593
# SCORE: 		0.589
# SCORE: 		0.642
# SCORE: 		0.631
# SCORE: 		0.652
# SCORE: 		0.544
# SCORE: 		0.607
# SCORE: 		0.537
# SCORE: 		0.551
# SCORE: 		0.585
# SCORE: 		0.635
# SCORE: 		0.657
# SCORE: 		0.632
# SCORE: 		0.609
# SCORE: 		0.600
# SCORE: 		0.651
# SCORE: 		0.565
# SCORE: 		0.648
# SCORE: 		0.627
# SCORE: 		0.547
# SCORE: 		0.592
# SCORE: 		0.583
# SCORE: 		0.658
# SCORE: 		0.622
# SCORE: 		0.652
# SCORE: 		0.631
# SCORE: 		0.655
# SCORE: 		0.656
# SCORE: 		0.629
# SCORE: 		0.642
# SCORE: 		0.631
# SCORE: 		0.610
# SCORE: 		0.654
# SCORE: 		0.629
# SCORE: 		0.645
# SCORE: 		0.637
# SCORE: 		0.602
# SCORE: 		0.653
# SCORE: 		0.536
# SCORE: 		0.625
# SCORE: 		0.629
# SCORE: 		0.623
# SCORE: 		0.640
# SCORE: 		0.614
# SCORE: 		0.607
# SCORE: 		0.598
# SCORE: 		0.657
# SCORE: 		0.547
# SCORE: 		0.653
# SCORE: 		0.629
# SCORE: 		0.614
# SCORE: 		0.548
# SCORE: 		0.627
# SCORE: 		0.560
# SCORE: 		0.638
# SCORE: 		0.659
# SCORE: 		0.657
# SCORE: 		0.594
# SCORE: 		0.647
# SCORE: 		0.659
# SCORE: 		0.598
# SCORE: 		0.593
# SCORE: 		0.623
# SCORE: 		0.639
# SCORE: 		0.654
# SCORE: 		0.651
# SCORE: 		0.604
# SCORE: 		0.619
# SCORE: 		0.639
# SCORE: 		0.657
# SCORE: 		0.551
# SCORE: 		0.577
# SCORE: 		0.613
# SCORE: 		0.624
# SCORE: 		0.645
# SCORE: 		0.636
# SCORE: 		0.569
# SCORE: 		0.607
# SCORE: 		0.618
# SCORE: 		0.594
# SCORE: 		0.626
# SCORE: 		0.633
# SCORE: 		0.638
# SCORE: 		0.653
# SCORE: 		0.659
# SCORE: 		0.542
# SCORE: 		0.654
# SCORE: 		0.578
# SCORE: 		0.617
# SCORE: 		0.640
# SCORE: 		0.650
# SCORE: 		0.619
# SCORE: 		0.631
# SCORE: 		0.548
# SCORE: 		0.638
# SCORE: 		0.622
# SCORE: 		0.624
# SCORE: 		0.574
# SCORE: 		0.629
# SCORE: 		0.660
# SCORE: 		0.577
# SCORE: 		0.648
# SCORE: 		0.603
# SCORE: 		0.560
# SCORE: 		0.654
# SCORE: 		0.659
# SCORE: 		0.658
# SCORE: 		0.640
# SCORE: 		0.645
# SCORE: 		0.635
# SCORE: 		0.659
# SCORE: 		0.639
# SCORE: 		0.653
# SCORE: 		0.638
# SCORE: 		0.660
# SCORE: 		0.659
# SCORE: 		0.640
# SCORE: 		0.661
# SCORE: 		0.650
# SCORE: 		0.639
# SCORE: 		0.627
# SCORE: 		0.660
# SCORE: 		0.637
# SCORE: 		0.622
# SCORE: 		0.653
# SCORE: 		0.611
# SCORE: 		0.635
# SCORE: 		0.574
# SCORE: 		0.649
# SCORE: 		0.630
# SCORE: 		0.592
# SCORE: 		0.600
# SCORE: 		0.633
# SCORE: 		0.658
# SCORE: 		0.630
# SCORE: 		0.650
# SCORE: 		0.639
# SCORE: 		0.660
# SCORE: 		0.637
# SCORE: 		0.631
# SCORE: 		0.614
# SCORE: 		0.655
# SCORE: 		0.611
# SCORE: 		0.638
# SCORE: 		0.653
# SCORE: 		0.619
# SCORE: 		0.643
# SCORE: 		0.643
# SCORE: 		0.657
# SCORE: 		0.631
# SCORE: 		0.637
# SCORE: 		0.632
# SCORE: 		0.595
# SCORE: 		0.550
# SCORE: 		0.655
# SCORE: 		0.647
# SCORE: 		0.639
# SCORE: 		0.630
# SCORE: 		0.654
# SCORE: 		0.614
# SCORE: 		0.645
# SCORE: 		0.614
# SCORE: 		0.632
# SCORE: 		0.652
# SCORE: 		0.652
# SCORE: 		0.630
# SCORE: 		0.604
# SCORE: 		0.641
# SCORE: 		0.660
# SCORE: 		0.624
# SCORE: 		0.629
# SCORE: 		0.658
# SCORE: 		0.589
# SCORE: 		0.653
# SCORE: 		0.619
# SCORE: 		0.541
# SCORE: 		0.647
# SCORE: 		0.605
# SCORE: 		0.630
# SCORE: 		0.647
# SCORE: 		0.635
# SCORE: 		0.568
# SCORE: 		0.574
# SCORE: 		0.558
# SCORE: 		0.582
# SCORE: 		0.615
# SCORE: 		0.651
# SCORE: 		0.642
# SCORE: 		0.620
# SCORE: 		0.560
# SCORE: 		0.659
# SCORE: 		0.625
# SCORE: 		0.629
# SCORE: 		0.643
# SCORE: 		0.654
# SCORE: 		0.617
# SCORE: 		0.646
# SCORE: 		0.653
# SCORE: 		0.593
# SCORE: 		0.631
# SCORE: 		0.628
# SCORE: 		0.548
# SCORE: 		0.656
# SCORE: 		0.632
# SCORE: 		0.592
# SCORE: 		0.556
# SCORE: 		0.643
# SCORE: 		0.656
# SCORE: 		0.623
# SCORE: 		0.626
# SCORE: 		0.632
# SCORE: 		0.606
# SCORE: 		0.658
# SCORE: 		0.634
# SCORE: 		0.649
# SCORE: 		0.635
# SCORE: 		0.660
# SCORE: 		0.661
# SCORE: 		0.653
# SCORE: 		0.648
# SCORE: 		0.643
# SCORE: 		0.660
# SCORE: 		0.639
# SCORE: 		0.655
# SCORE: 		0.638
# SCORE: 		0.661
# SCORE: 		0.645
# SCORE: 		0.659
# SCORE: 		0.658
# SCORE: 		0.633
# SCORE: 		0.648
# SCORE: 		0.637
# SCORE: 		0.649
# SCORE: 		0.657
# SCORE: 		0.635
# SCORE: 		0.651
# SCORE: 		0.635
# SCORE: 		0.633
# SCORE: 		0.645
# ...
# SCORE: 		0.629
# SCORE: 		0.650
# SCORE: 		0.628
# SCORE: 		0.645
# SCORE: 		0.657
# SCORE: 		0.574
# SCORE: 		0.638
# SCORE: 		0.655
# SCORE: 		0.654
# SCORE: 		0.600
# SCORE: 		0.642
# SCORE: 		0.650
# SCORE: 		0.604
# SCORE: 		0.661
# SCORE: 		0.649
# SCORE: 		0.658
# SCORE: 		0.633
# SCORE: 		0.656
# SCORE: 		0.649
# SCORE: 		0.645
# SCORE: 		0.642
# SCORE: 		0.654
# SCORE: 		0.654
# SCORE: 		0.645
# SCORE: 		0.624
# SCORE: 		0.661
# SCORE: 		0.619
# SCORE: 		0.639
# SCORE: 		0.631
# SCORE: 		0.651
# SCORE: 		0.658
# SCORE: 		0.660
# SCORE: 		0.650
# SCORE: 		0.568
# SCORE: 		0.641
# SCORE: 		0.637
# SCORE: 		0.660
# SCORE: 		0.642
# SCORE: 		0.631
# SCORE: 		0.650
# SCORE: 		0.635
# SCORE: 		0.599
# SCORE: 		0.658
# SCORE: 		0.653
# SCORE: 		0.658
# SCORE: 		0.639
# SCORE: 		0.646
# SCORE: 		0.629
# SCORE: 		0.645
# SCORE: 		0.655
# SCORE: 		0.643
# SCORE: 		0.634
# SCORE: 		0.626
# SCORE: 		0.655
# SCORE: 		0.649
# SCORE: 		0.637
# SCORE: 		0.658
# SCORE: 		0.640
# SCORE: 		0.645
# SCORE: 		0.652
# SCORE: 		0.653
# SCORE: 		0.632
# SCORE: 		0.595
# SCORE: 		0.642
# SCORE: 		0.655
# SCORE: 		0.661
# SCORE: 		0.657
# SCORE: 		0.641
# SCORE: 		0.651
# SCORE: 		0.632
# SCORE: 		0.655
# SCORE: 		0.654
# SCORE: 		0.644
# SCORE: 		0.632
# SCORE: 		0.659
# SCORE: 		0.649
# SCORE: 		0.599
# SCORE: 		0.653
# SCORE: 		0.661
# SCORE: 		0.644
# SCORE: 		0.658
# SCORE: 		0.630
# SCORE: 		0.577
# SCORE: 		0.649
# SCORE: 		0.632
# SCORE: 		0.642
# SCORE: 		0.644
# SCORE: 		0.614
# SCORE: 		0.656
# SCORE: 		0.634
# SCORE: 		0.656
# SCORE: 		0.644
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [20:53<00:00,  1.25s/trial, best loss: -0.6616395219576261]

# %%
with open('study_gb_linear_features_wo_dec_scalePosWeights_1.pickle', 'wb') as handle:
    pickle.dump(trials_standard, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('params_gb_linear_features_wo_dec_scalePosWeights_1.pickle', 'wb') as handle:
    pickle.dump(best_hyperparams_standard, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
    
with open('study_gb_linear_features_with_dec_scalePosWeights_1.pickle', 'wb') as handle:
    pickle.dump(trials_dec, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('params_gb_linear_features_with_dec_scalePosWeights_1.pickle', 'wb') as handle:
    pickle.dump(best_hyperparams_dec, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
best_params_list = []
file_names = [('params_gb_linear_features_wo_dec_scalePosWeights_1.pickle', 'Feature_DS'), 
              ('params_gb_linear_features_with_dec_scalePosWeights_1.pickle', 'DEC_Feature_DS'), 
              ('params_gb_linear_features_wo_dec.pickle', 'Feature_DS'), 
              ('params_gb_linear_features_with_dec.pickle', 'DEC_Feature_DS')]

params={'objective': 'binary:logistic',
        'scale_pos_weight': 6,
        'updater': 'shotgun',
        'verbosity': 0,
        'booster': 'gblinear',
        'feature_selector': 'shuffle'
    }

for file_name, dataset_name in file_names:
    with (open(file_name, "rb")) as openfile:
        while True:
            try:
                best_params = pickle.load(openfile)
                
                for key, value in params.items():
                    best_params[key] = value
                    
                if file_name.find("1") != -1:
                    best_params["scale_pos_weight"] = 1
                else: 
                    best_params["scale_pos_weight"] = 6
                
                best_params_list.append((best_params, dataset_name))
            except EOFError:
                break
# Out:
# found 1
# found 1

# %%
print(best_params_list)
# Out:
# [({'alpha': 0.6833582677557102, 'lambda': 0.7519984324901798, 'learning_rate': 0.04038678123429325, 'num_boost_round': 420.1652147086029, 'objective': 'binary:logistic', 'scale_pos_weight': 1, 'updater': 'shotgun', 'verbosity': 0, 'booster': 'gblinear', 'feature_selector': 'shuffle'}, 'Feature_DS'), ({'alpha': 0.7973402678675838, 'lambda': 1.4393908525751467, 'learning_rate': 0.028671610518432145, 'num_boost_round': 746.5644975040432, 'objective': 'binary:logistic', 'scale_pos_weight': 1, 'updater': 'shotgun', 'verbosity': 0, 'booster': 'gblinear', 'feature_selector': 'shuffle'}, 'DEC_Feature_DS'), ({'alpha': 2.2012845190671833, 'lambda': 9.585749777482139, 'learning_rate': 0.06281582374305802, 'num_boost_round': 559.4507945736697, 'objective': 'binary:logistic', 'scale_pos_weight': 6, 'updater': 'shotgun', 'verbosity': 0, 'booster': 'gblinear', 'feature_selector': 'shuffle'}, 'Feature_DS'), ({'alpha': 3.669265694367747e-06, 'lambda': 0.003691484710585189, 'learning_rate': 0.0101804927699945, 'num_boost_round': 600.9232175086469, 'objective': 'binary:logistic', 'scale_pos_weight': 6, 'updater': 'shotgun', 'verbosity': 0, 'booster': 'gblinear', 'feature_selector': 'shuffle'}, 'DEC_Feature_DS')]

# %%
results = {}

n_estimators = 100
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits)

for params, dataset_name in best_params_list:
    
    if dataset_name == 'Feature_DS':
        train, test = X_train, X_test
    elif dataset_name == 'DEC_Feature_DS':
        train, test = X_train_full, X_test_full
    
    booster_params = params

#for train, test, booster_params, dataset_name in [(X_train, X_test, best_hyperparams_standard, 'Feature_DS'), (X_train_full, X_test_full, best_hyperparams_dec, 'DEC_Feature_DS')]:
    print(f'Evaluating {dataset_name} dataset')
    datasets_results = {}
    #for booster_type, booster_params in best_params[dataset_name].items():
    booster_type = 'gblinear'
    #booster_params = best_params['Feature_DS'][booster_type]
    
    print(booster_type)
    print(booster_params)
    #print(f'Bosster of type {booster_type} with params {booster_params}')
    booster_params['eval_metric'] = 'auc'
    cv_results = {'f1': [],
                  'roc': [],
                  'pr': [],
                  'rc': [],
                  'acc': [],
                  'eval_result': []
                 }
    #if booster_type == 'gblinear':
    #    continue
    for train_index, eval_index in skf.split(train, y_train):
        x_train_split = train[train.index.isin(train_index)]
        x_eval_split = train[train.index.isin(eval_index)]
        y_train_split = y_train[train_index]
        y_eval_split = y_train[eval_index]

        eval_set = [(x_train_split, y_train_split), (x_eval_split, y_eval_split)]

        xgb_default = xgb.XGBClassifier(**booster_params, n_estimators=n_estimators)
        xgb_default.fit(x_train_split, 
                      y_train_split, 
                      eval_set=eval_set, 
                       early_stopping_rounds=5)
        #print(x_train_split)
        #print(test)

        y_pred_proba = xgb_default.predict_proba(test)[:, 1]
        y_pred_classes = xgb_default.predict(test)
        cv_results['eval_result'].append(xgb_default.evals_result())

        cv_results['f1'].append(metrics.f1_score(y_test, y_pred_classes))
        cv_results['roc'].append(metrics.roc_auc_score(y_test, y_pred_classes))
        cv_results['acc'].append(metrics.balanced_accuracy_score(y_test, y_pred_classes))
        cv_results['pr'].append(metrics.precision_score(y_test, y_pred_classes))
        cv_results['rc'].append(metrics.recall_score(y_test, y_pred_classes))

    scores = {'ROC-AUC Score': [np.mean(np.array(cv_results['roc'])), np.std(np.array(cv_results['roc']))],
              'F1 Score': [np.mean(np.array(cv_results['f1'])), np.std(np.array(cv_results['f1']))],
              'Precision': [np.mean(np.array(cv_results['pr'])), np.std(np.array(cv_results['pr']))],
              'Recall': [np.mean(np.array(cv_results['rc'])), np.std(np.array(cv_results['rc']))],
              'Balanced Accuracy': [np.mean(np.array(cv_results['acc'])), np.std(np.array(cv_results['acc']))]}
    print('########## RESULTS ##########')
    print(json.dumps(scores, indent=4))
    print()
    datasets_results[booster_type] = {'proba_predictions': y_pred_proba,
                                      'class_predictions': y_pred_classes,
                                      'scores': scores,
                                      'eval_results': cv_results['eval_result']
                                     }
    results[dataset_name] = datasets_results

    print()
# Out:
# Evaluating Feature_DS dataset
# gblinear
# {'alpha': 0.6833582677557102, 'lambda': 0.7519984324901798, 'learning_rate': 0.04038678123429325, 'num_boost_round': 420.1652147086029, 'objective': 'binary:logistic', 'scale_pos_weight': 1, 'updater': 'shotgun', 'verbosity': 0, 'booster': 'gblinear', 'feature_selector': 'shuffle'}
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.58876	validation_1-auc:0.53409
# [1]	validation_0-auc:0.61897	validation_1-auc:0.55929
# [2]	validation_0-auc:0.64211	validation_1-auc:0.57551
# [3]	validation_0-auc:0.66015	validation_1-auc:0.58861
# [4]	validation_0-auc:0.67274	validation_1-auc:0.60033
# [5]	validation_0-auc:0.68263	validation_1-auc:0.60884
# [6]	validation_0-auc:0.69021	validation_1-auc:0.61596
# [7]	validation_0-auc:0.69608	validation_1-auc:0.62136
# [8]	validation_0-auc:0.70084	validation_1-auc:0.62571
# [9]	validation_0-auc:0.70482	validation_1-auc:0.62958
# [10]	validation_0-auc:0.70818	validation_1-auc:0.63275
# [11]	validation_0-auc:0.71078	validation_1-auc:0.63522
# [12]	validation_0-auc:0.71308	validation_1-auc:0.63697
# [13]	validation_0-auc:0.71503	validation_1-auc:0.63906
# [14]	validation_0-auc:0.71686	validation_1-auc:0.63999
# [15]	validation_0-auc:0.71825	validation_1-auc:0.64101
# [16]	validation_0-auc:0.71943	validation_1-auc:0.64172
# [17]	validation_0-auc:0.72056	validation_1-auc:0.64300
# [18]	validation_0-auc:0.72155	validation_1-auc:0.64426
# [19]	validation_0-auc:0.72246	validation_1-auc:0.64482
# [20]	validation_0-auc:0.72324	validation_1-auc:0.64521
# [21]	validation_0-auc:0.72400	validation_1-auc:0.64569
# [22]	validation_0-auc:0.72473	validation_1-auc:0.64609
# [23]	validation_0-auc:0.72533	validation_1-auc:0.64662
# [24]	validation_0-auc:0.72585	validation_1-auc:0.64725
# [25]	validation_0-auc:0.72634	validation_1-auc:0.64792
# [26]	validation_0-auc:0.72677	validation_1-auc:0.64797
# [27]	validation_0-auc:0.72718	validation_1-auc:0.64817
# [28]	validation_0-auc:0.72773	validation_1-auc:0.64866
# [29]	validation_0-auc:0.72805	validation_1-auc:0.64863
# [30]	validation_0-auc:0.72852	validation_1-auc:0.64874
# [31]	validation_0-auc:0.72894	validation_1-auc:0.64914
# [32]	validation_0-auc:0.72927	validation_1-auc:0.64957
# [33]	validation_0-auc:0.72959	validation_1-auc:0.64972
# [34]	validation_0-auc:0.72982	validation_1-auc:0.65019
# [35]	validation_0-auc:0.73001	validation_1-auc:0.65043
# [36]	validation_0-auc:0.73027	validation_1-auc:0.65049
# [37]	validation_0-auc:0.73046	validation_1-auc:0.65049
# [38]	validation_0-auc:0.73060	validation_1-auc:0.65053
# [39]	validation_0-auc:0.73087	validation_1-auc:0.65059
# [40]	validation_0-auc:0.73105	validation_1-auc:0.65090
# [41]	validation_0-auc:0.73123	validation_1-auc:0.65113
# [42]	validation_0-auc:0.73140	validation_1-auc:0.65111
# [43]	validation_0-auc:0.73155	validation_1-auc:0.65147
# [44]	validation_0-auc:0.73169	validation_1-auc:0.65156
# [45]	validation_0-auc:0.73178	validation_1-auc:0.65178
# [46]	validation_0-auc:0.73191	validation_1-auc:0.65190
# [47]	validation_0-auc:0.73205	validation_1-auc:0.65187
# [48]	validation_0-auc:0.73222	validation_1-auc:0.65190
# [49]	validation_0-auc:0.73235	validation_1-auc:0.65168
# [50]	validation_0-auc:0.73250	validation_1-auc:0.65180
# [51]	validation_0-auc:0.73260	validation_1-auc:0.65197
# [52]	validation_0-auc:0.73270	validation_1-auc:0.65184
# [53]	validation_0-auc:0.73279	validation_1-auc:0.65184
# [54]	validation_0-auc:0.73293	validation_1-auc:0.65184
# [55]	validation_0-auc:0.73309	validation_1-auc:0.65183
# [0]	validation_0-auc:0.59105	validation_1-auc:0.54979
# [1]	validation_0-auc:0.62555	validation_1-auc:0.57431
# [2]	validation_0-auc:0.64867	validation_1-auc:0.59168
# [3]	validation_0-auc:0.66363	validation_1-auc:0.60564
# [4]	validation_0-auc:0.67461	validation_1-auc:0.61523
# [5]	validation_0-auc:0.68289	validation_1-auc:0.62299
# [6]	validation_0-auc:0.68941	validation_1-auc:0.62915
# [7]	validation_0-auc:0.69480	validation_1-auc:0.63388
# [8]	validation_0-auc:0.69903	validation_1-auc:0.63820
# [9]	validation_0-auc:0.70257	validation_1-auc:0.64170
# [10]	validation_0-auc:0.70557	validation_1-auc:0.64533
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11]	validation_0-auc:0.70816	validation_1-auc:0.64769
# [12]	validation_0-auc:0.71041	validation_1-auc:0.65031
# [13]	validation_0-auc:0.71238	validation_1-auc:0.65243
# [14]	validation_0-auc:0.71419	validation_1-auc:0.65397
# [15]	validation_0-auc:0.71568	validation_1-auc:0.65538
# [16]	validation_0-auc:0.71710	validation_1-auc:0.65668
# [17]	validation_0-auc:0.71843	validation_1-auc:0.65802
# [18]	validation_0-auc:0.71949	validation_1-auc:0.65836
# [19]	validation_0-auc:0.72054	validation_1-auc:0.65888
# [20]	validation_0-auc:0.72147	validation_1-auc:0.65972
# [21]	validation_0-auc:0.72216	validation_1-auc:0.66042
# [22]	validation_0-auc:0.72291	validation_1-auc:0.66127
# [23]	validation_0-auc:0.72359	validation_1-auc:0.66157
# [24]	validation_0-auc:0.72426	validation_1-auc:0.66212
# [25]	validation_0-auc:0.72474	validation_1-auc:0.66244
# [26]	validation_0-auc:0.72528	validation_1-auc:0.66252
# [27]	validation_0-auc:0.72580	validation_1-auc:0.66277
# [28]	validation_0-auc:0.72622	validation_1-auc:0.66285
# [29]	validation_0-auc:0.72659	validation_1-auc:0.66286
# [30]	validation_0-auc:0.72701	validation_1-auc:0.66255
# [31]	validation_0-auc:0.72744	validation_1-auc:0.66251
# [32]	validation_0-auc:0.72784	validation_1-auc:0.66260
# [33]	validation_0-auc:0.72825	validation_1-auc:0.66249
# [0]	validation_0-auc:0.57467	validation_1-auc:0.57677
# [1]	validation_0-auc:0.60770	validation_1-auc:0.60791
# [2]	validation_0-auc:0.63251	validation_1-auc:0.63381
# [3]	validation_0-auc:0.65057	validation_1-auc:0.65092
# [4]	validation_0-auc:0.66418	validation_1-auc:0.66293
# [5]	validation_0-auc:0.67534	validation_1-auc:0.67074
# [6]	validation_0-auc:0.68443	validation_1-auc:0.67797
# [7]	validation_0-auc:0.69132	validation_1-auc:0.68332
# [8]	validation_0-auc:0.69719	validation_1-auc:0.68764
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [9]	validation_0-auc:0.70165	validation_1-auc:0.69058
# [10]	validation_0-auc:0.70538	validation_1-auc:0.69345
# [11]	validation_0-auc:0.70862	validation_1-auc:0.69520
# [12]	validation_0-auc:0.71136	validation_1-auc:0.69644
# [13]	validation_0-auc:0.71346	validation_1-auc:0.69703
# [14]	validation_0-auc:0.71542	validation_1-auc:0.69819
# [15]	validation_0-auc:0.71723	validation_1-auc:0.69791
# [16]	validation_0-auc:0.71856	validation_1-auc:0.69803
# [17]	validation_0-auc:0.71978	validation_1-auc:0.69814
# [18]	validation_0-auc:0.72102	validation_1-auc:0.69802
# [0]	validation_0-auc:0.57475	validation_1-auc:0.58490
# [1]	validation_0-auc:0.60875	validation_1-auc:0.59488
# [2]	validation_0-auc:0.63748	validation_1-auc:0.60427
# [3]	validation_0-auc:0.65716	validation_1-auc:0.60868
# [4]	validation_0-auc:0.67145	validation_1-auc:0.61293
# [5]	validation_0-auc:0.68241	validation_1-auc:0.61583
# [6]	validation_0-auc:0.69126	validation_1-auc:0.61774
# [7]	validation_0-auc:0.69810	validation_1-auc:0.62031
# [8]	validation_0-auc:0.70373	validation_1-auc:0.62267
# [9]	validation_0-auc:0.70834	validation_1-auc:0.62343
# [10]	validation_0-auc:0.71237	validation_1-auc:0.62468
# [11]	validation_0-auc:0.71572	validation_1-auc:0.62485
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [12]	validation_0-auc:0.71862	validation_1-auc:0.62509
# [13]	validation_0-auc:0.72110	validation_1-auc:0.62533
# [14]	validation_0-auc:0.72322	validation_1-auc:0.62601
# [15]	validation_0-auc:0.72502	validation_1-auc:0.62629
# [16]	validation_0-auc:0.72664	validation_1-auc:0.62674
# [17]	validation_0-auc:0.72816	validation_1-auc:0.62643
# [18]	validation_0-auc:0.72939	validation_1-auc:0.62618
# [19]	validation_0-auc:0.73047	validation_1-auc:0.62644
# [20]	validation_0-auc:0.73149	validation_1-auc:0.62673
# [21]	validation_0-auc:0.73236	validation_1-auc:0.62681
# [22]	validation_0-auc:0.73318	validation_1-auc:0.62693
# [23]	validation_0-auc:0.73396	validation_1-auc:0.62639
# [24]	validation_0-auc:0.73464	validation_1-auc:0.62632
# [25]	validation_0-auc:0.73520	validation_1-auc:0.62601
# [26]	validation_0-auc:0.73581	validation_1-auc:0.62597
# [0]	validation_0-auc:0.56020	validation_1-auc:0.61737
# [1]	validation_0-auc:0.59438	validation_1-auc:0.65399
# [2]	validation_0-auc:0.62274	validation_1-auc:0.67652
# [3]	validation_0-auc:0.64371	validation_1-auc:0.69030
# [4]	validation_0-auc:0.65971	validation_1-auc:0.69757
# [5]	validation_0-auc:0.67207	validation_1-auc:0.70168
# [6]	validation_0-auc:0.68215	validation_1-auc:0.70197
# [7]	validation_0-auc:0.69013	validation_1-auc:0.70203
# [8]	validation_0-auc:0.69684	validation_1-auc:0.70106
# [9]	validation_0-auc:0.70198	validation_1-auc:0.70047
# [10]	validation_0-auc:0.70615	validation_1-auc:0.69948
# [11]	validation_0-auc:0.70961	validation_1-auc:0.69735
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ########## RESULTS ##########
# {
#     "ROC-AUC Score": [
#         0.4996584116140051,
#         0.0001707941929974366
#     ],
#     "F1 Score": [
#         0.0,
#         0.0
#     ],
#     "Precision": [
#         0.0,
#         0.0
#     ],
#     "Recall": [
#         0.0,
#         0.0
#     ],
#     "Balanced Accuracy": [
#         0.4996584116140051,
#         0.0001707941929974366
#     ]
# }
#
#
# Evaluating DEC_Feature_DS dataset
# gblinear
# {'alpha': 0.7973402678675838, 'lambda': 1.4393908525751467, 'learning_rate': 0.028671610518432145, 'num_boost_round': 746.5644975040432, 'objective': 'binary:logistic', 'scale_pos_weight': 1, 'updater': 'shotgun', 'verbosity': 0, 'booster': 'gblinear', 'feature_selector': 'shuffle'}
# [0]	validation_0-auc:0.57950	validation_1-auc:0.52135
# [1]	validation_0-auc:0.60522	validation_1-auc:0.54088
# [2]	validation_0-auc:0.62530	validation_1-auc:0.55742
# [3]	validation_0-auc:0.64071	validation_1-auc:0.56973
# [4]	validation_0-auc:0.65256	validation_1-auc:0.58019
# [5]	validation_0-auc:0.66239	validation_1-auc:0.58849
# [6]	validation_0-auc:0.67023	validation_1-auc:0.59559
# [7]	validation_0-auc:0.67673	validation_1-auc:0.60189
# [8]	validation_0-auc:0.68215	validation_1-auc:0.60760
# [9]	validation_0-auc:0.68681	validation_1-auc:0.61200
# [10]	validation_0-auc:0.69092	validation_1-auc:0.61448
# [11]	validation_0-auc:0.69450	validation_1-auc:0.61725
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [12]	validation_0-auc:0.69743	validation_1-auc:0.62033
# [13]	validation_0-auc:0.69997	validation_1-auc:0.62259
# [14]	validation_0-auc:0.70212	validation_1-auc:0.62509
# [15]	validation_0-auc:0.70400	validation_1-auc:0.62687
# [16]	validation_0-auc:0.70574	validation_1-auc:0.62888
# [17]	validation_0-auc:0.70740	validation_1-auc:0.63080
# [18]	validation_0-auc:0.70882	validation_1-auc:0.63191
# [19]	validation_0-auc:0.71008	validation_1-auc:0.63295
# [20]	validation_0-auc:0.71118	validation_1-auc:0.63441
# [21]	validation_0-auc:0.71216	validation_1-auc:0.63607
# [22]	validation_0-auc:0.71299	validation_1-auc:0.63667
# [23]	validation_0-auc:0.71376	validation_1-auc:0.63722
# [24]	validation_0-auc:0.71452	validation_1-auc:0.63811
# [25]	validation_0-auc:0.71520	validation_1-auc:0.63890
# [26]	validation_0-auc:0.71589	validation_1-auc:0.63944
# [27]	validation_0-auc:0.71647	validation_1-auc:0.64000
# [28]	validation_0-auc:0.71703	validation_1-auc:0.64082
# [29]	validation_0-auc:0.71764	validation_1-auc:0.64141
# [30]	validation_0-auc:0.71806	validation_1-auc:0.64172
# [31]	validation_0-auc:0.71854	validation_1-auc:0.64183
# [32]	validation_0-auc:0.71897	validation_1-auc:0.64250
# [33]	validation_0-auc:0.71943	validation_1-auc:0.64275
# [34]	validation_0-auc:0.71980	validation_1-auc:0.64300
# [35]	validation_0-auc:0.72006	validation_1-auc:0.64342
# [36]	validation_0-auc:0.72040	validation_1-auc:0.64339
# [37]	validation_0-auc:0.72063	validation_1-auc:0.64336
# [38]	validation_0-auc:0.72096	validation_1-auc:0.64355
# [39]	validation_0-auc:0.72120	validation_1-auc:0.64389
# [40]	validation_0-auc:0.72145	validation_1-auc:0.64417
# [41]	validation_0-auc:0.72171	validation_1-auc:0.64434
# [42]	validation_0-auc:0.72192	validation_1-auc:0.64475
# [43]	validation_0-auc:0.72215	validation_1-auc:0.64503
# [44]	validation_0-auc:0.72239	validation_1-auc:0.64526
# [45]	validation_0-auc:0.72261	validation_1-auc:0.64560
# [46]	validation_0-auc:0.72285	validation_1-auc:0.64594
# [47]	validation_0-auc:0.72302	validation_1-auc:0.64611
# [48]	validation_0-auc:0.72317	validation_1-auc:0.64628
# [49]	validation_0-auc:0.72334	validation_1-auc:0.64628
# [50]	validation_0-auc:0.72352	validation_1-auc:0.64636
# [51]	validation_0-auc:0.72372	validation_1-auc:0.64646
# [52]	validation_0-auc:0.72378	validation_1-auc:0.64631
# [53]	validation_0-auc:0.72391	validation_1-auc:0.64647
# [54]	validation_0-auc:0.72408	validation_1-auc:0.64670
# [55]	validation_0-auc:0.72419	validation_1-auc:0.64676
# [56]	validation_0-auc:0.72427	validation_1-auc:0.64663
# [57]	validation_0-auc:0.72441	validation_1-auc:0.64685
# [58]	validation_0-auc:0.72451	validation_1-auc:0.64689
# [59]	validation_0-auc:0.72463	validation_1-auc:0.64692
# [60]	validation_0-auc:0.72468	validation_1-auc:0.64686
# [61]	validation_0-auc:0.72479	validation_1-auc:0.64711
# [62]	validation_0-auc:0.72493	validation_1-auc:0.64711
# [63]	validation_0-auc:0.72498	validation_1-auc:0.64715
# [64]	validation_0-auc:0.72504	validation_1-auc:0.64723
# [65]	validation_0-auc:0.72505	validation_1-auc:0.64710
# [66]	validation_0-auc:0.72511	validation_1-auc:0.64707
# [67]	validation_0-auc:0.72522	validation_1-auc:0.64721
# [68]	validation_0-auc:0.72532	validation_1-auc:0.64709
# [69]	validation_0-auc:0.72538	validation_1-auc:0.64722
# [0]	validation_0-auc:0.58562	validation_1-auc:0.53841
# [1]	validation_0-auc:0.60954	validation_1-auc:0.55699
# [2]	validation_0-auc:0.62917	validation_1-auc:0.57037
# [3]	validation_0-auc:0.64379	validation_1-auc:0.58148
# [4]	validation_0-auc:0.65475	validation_1-auc:0.59101
# [5]	validation_0-auc:0.66327	validation_1-auc:0.59882
# [6]	validation_0-auc:0.67045	validation_1-auc:0.60494
# [7]	validation_0-auc:0.67643	validation_1-auc:0.61074
# [8]	validation_0-auc:0.68129	validation_1-auc:0.61557
# [9]	validation_0-auc:0.68542	validation_1-auc:0.61970
# [10]	validation_0-auc:0.68893	validation_1-auc:0.62267
# [11]	validation_0-auc:0.69189	validation_1-auc:0.62623
# [12]	validation_0-auc:0.69467	validation_1-auc:0.62891
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13]	validation_0-auc:0.69710	validation_1-auc:0.63136
# [14]	validation_0-auc:0.69923	validation_1-auc:0.63341
# [15]	validation_0-auc:0.70111	validation_1-auc:0.63593
# [16]	validation_0-auc:0.70293	validation_1-auc:0.63765
# [17]	validation_0-auc:0.70445	validation_1-auc:0.63972
# [18]	validation_0-auc:0.70577	validation_1-auc:0.64159
# [19]	validation_0-auc:0.70690	validation_1-auc:0.64315
# [20]	validation_0-auc:0.70815	validation_1-auc:0.64362
# [21]	validation_0-auc:0.70920	validation_1-auc:0.64477
# [22]	validation_0-auc:0.71015	validation_1-auc:0.64561
# [23]	validation_0-auc:0.71110	validation_1-auc:0.64670
# [24]	validation_0-auc:0.71195	validation_1-auc:0.64750
# [25]	validation_0-auc:0.71272	validation_1-auc:0.64851
# [26]	validation_0-auc:0.71326	validation_1-auc:0.64918
# [27]	validation_0-auc:0.71383	validation_1-auc:0.64999
# [28]	validation_0-auc:0.71437	validation_1-auc:0.65056
# [29]	validation_0-auc:0.71490	validation_1-auc:0.65141
# [30]	validation_0-auc:0.71535	validation_1-auc:0.65220
# [31]	validation_0-auc:0.71581	validation_1-auc:0.65240
# [32]	validation_0-auc:0.71628	validation_1-auc:0.65274
# [33]	validation_0-auc:0.71667	validation_1-auc:0.65313
# [34]	validation_0-auc:0.71707	validation_1-auc:0.65308
# [35]	validation_0-auc:0.71737	validation_1-auc:0.65332
# [36]	validation_0-auc:0.71785	validation_1-auc:0.65361
# [37]	validation_0-auc:0.71815	validation_1-auc:0.65382
# [38]	validation_0-auc:0.71847	validation_1-auc:0.65414
# [39]	validation_0-auc:0.71877	validation_1-auc:0.65426
# [40]	validation_0-auc:0.71901	validation_1-auc:0.65442
# [41]	validation_0-auc:0.71927	validation_1-auc:0.65458
# [42]	validation_0-auc:0.71953	validation_1-auc:0.65480
# [43]	validation_0-auc:0.71973	validation_1-auc:0.65492
# [44]	validation_0-auc:0.71989	validation_1-auc:0.65500
# [45]	validation_0-auc:0.72006	validation_1-auc:0.65525
# [46]	validation_0-auc:0.72030	validation_1-auc:0.65504
# [47]	validation_0-auc:0.72046	validation_1-auc:0.65521
# [48]	validation_0-auc:0.72064	validation_1-auc:0.65544
# [49]	validation_0-auc:0.72084	validation_1-auc:0.65557
# [50]	validation_0-auc:0.72101	validation_1-auc:0.65557
# [51]	validation_0-auc:0.72121	validation_1-auc:0.65595
# [52]	validation_0-auc:0.72142	validation_1-auc:0.65604
# [53]	validation_0-auc:0.72151	validation_1-auc:0.65587
# [54]	validation_0-auc:0.72169	validation_1-auc:0.65572
# [55]	validation_0-auc:0.72184	validation_1-auc:0.65573
# [56]	validation_0-auc:0.72195	validation_1-auc:0.65572
# [57]	validation_0-auc:0.72211	validation_1-auc:0.65582
# [0]	validation_0-auc:0.57020	validation_1-auc:0.57018
# [1]	validation_0-auc:0.59442	validation_1-auc:0.59386
# [2]	validation_0-auc:0.61471	validation_1-auc:0.61416
# [3]	validation_0-auc:0.63034	validation_1-auc:0.63101
# [4]	validation_0-auc:0.64311	validation_1-auc:0.64448
# [5]	validation_0-auc:0.65341	validation_1-auc:0.65489
# [6]	validation_0-auc:0.66209	validation_1-auc:0.66251
# [7]	validation_0-auc:0.66947	validation_1-auc:0.67046
# [8]	validation_0-auc:0.67557	validation_1-auc:0.67516
# [9]	validation_0-auc:0.68087	validation_1-auc:0.68029
# [10]	validation_0-auc:0.68537	validation_1-auc:0.68422
# [11]	validation_0-auc:0.68921	validation_1-auc:0.68730
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [12]	validation_0-auc:0.69263	validation_1-auc:0.69054
# [13]	validation_0-auc:0.69555	validation_1-auc:0.69234
# [14]	validation_0-auc:0.69814	validation_1-auc:0.69403
# [15]	validation_0-auc:0.70044	validation_1-auc:0.69566
# [16]	validation_0-auc:0.70234	validation_1-auc:0.69695
# [17]	validation_0-auc:0.70430	validation_1-auc:0.69776
# [18]	validation_0-auc:0.70602	validation_1-auc:0.69868
# [19]	validation_0-auc:0.70727	validation_1-auc:0.69963
# [20]	validation_0-auc:0.70856	validation_1-auc:0.69990
# [21]	validation_0-auc:0.70974	validation_1-auc:0.70014
# [22]	validation_0-auc:0.71072	validation_1-auc:0.70010
# [23]	validation_0-auc:0.71173	validation_1-auc:0.70033
# [24]	validation_0-auc:0.71254	validation_1-auc:0.70045
# [25]	validation_0-auc:0.71332	validation_1-auc:0.70056
# [26]	validation_0-auc:0.71388	validation_1-auc:0.70067
# [27]	validation_0-auc:0.71445	validation_1-auc:0.70044
# [28]	validation_0-auc:0.71494	validation_1-auc:0.70029
# [29]	validation_0-auc:0.71548	validation_1-auc:0.70020
# [30]	validation_0-auc:0.71598	validation_1-auc:0.69994
# [31]	validation_0-auc:0.71647	validation_1-auc:0.69966
# [0]	validation_0-auc:0.58384	validation_1-auc:0.59897
# [1]	validation_0-auc:0.60150	validation_1-auc:0.60071
# [2]	validation_0-auc:0.62404	validation_1-auc:0.60446
# [3]	validation_0-auc:0.64158	validation_1-auc:0.60978
# [4]	validation_0-auc:0.65513	validation_1-auc:0.61331
# [5]	validation_0-auc:0.66572	validation_1-auc:0.61438
# [6]	validation_0-auc:0.67445	validation_1-auc:0.61594
# [7]	validation_0-auc:0.68131	validation_1-auc:0.61749
# [8]	validation_0-auc:0.68745	validation_1-auc:0.61882
# [9]	validation_0-auc:0.69219	validation_1-auc:0.61941
# [10]	validation_0-auc:0.69650	validation_1-auc:0.62119
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11]	validation_0-auc:0.70013	validation_1-auc:0.62243
# [12]	validation_0-auc:0.70332	validation_1-auc:0.62325
# [13]	validation_0-auc:0.70589	validation_1-auc:0.62428
# [14]	validation_0-auc:0.70828	validation_1-auc:0.62435
# [15]	validation_0-auc:0.71041	validation_1-auc:0.62465
# [16]	validation_0-auc:0.71215	validation_1-auc:0.62479
# [17]	validation_0-auc:0.71403	validation_1-auc:0.62472
# [18]	validation_0-auc:0.71547	validation_1-auc:0.62507
# [19]	validation_0-auc:0.71678	validation_1-auc:0.62502
# [20]	validation_0-auc:0.71803	validation_1-auc:0.62510
# [21]	validation_0-auc:0.71910	validation_1-auc:0.62511
# [22]	validation_0-auc:0.72002	validation_1-auc:0.62509
# [23]	validation_0-auc:0.72087	validation_1-auc:0.62522
# [24]	validation_0-auc:0.72175	validation_1-auc:0.62514
# [25]	validation_0-auc:0.72245	validation_1-auc:0.62434
# [26]	validation_0-auc:0.72320	validation_1-auc:0.62389
# [27]	validation_0-auc:0.72382	validation_1-auc:0.62399
# [28]	validation_0-auc:0.72440	validation_1-auc:0.62367
# [0]	validation_0-auc:0.56351	validation_1-auc:0.60602
# [1]	validation_0-auc:0.58298	validation_1-auc:0.62998
# [2]	validation_0-auc:0.60309	validation_1-auc:0.65025
# [3]	validation_0-auc:0.62042	validation_1-auc:0.66621
# [4]	validation_0-auc:0.63472	validation_1-auc:0.67761
# [5]	validation_0-auc:0.64671	validation_1-auc:0.68513
# [6]	validation_0-auc:0.65687	validation_1-auc:0.68988
# [7]	validation_0-auc:0.66568	validation_1-auc:0.69366
# [8]	validation_0-auc:0.67324	validation_1-auc:0.69653
# [9]	validation_0-auc:0.67959	validation_1-auc:0.69750
# [10]	validation_0-auc:0.68512	validation_1-auc:0.69825
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [11]	validation_0-auc:0.68978	validation_1-auc:0.69784
# [12]	validation_0-auc:0.69381	validation_1-auc:0.69792
# [13]	validation_0-auc:0.69734	validation_1-auc:0.69717
# [14]	validation_0-auc:0.70029	validation_1-auc:0.69646
# [15]	validation_0-auc:0.70284	validation_1-auc:0.69570
# ########## RESULTS ##########
# {
#     "ROC-AUC Score": [
#         0.4996584116140051,
#         0.0001707941929974366
#     ],
#     "F1 Score": [
#         0.0,
#         0.0
#     ],
#     "Precision": [
#         0.0,
#         0.0
#     ],
#     "Recall": [
#         0.0,
#         0.0
#     ],
#     "Balanced Accuracy": [
#         0.4996584116140051,
#         0.0001707941929974366
#     ]
# }
#
#
# Evaluating Feature_DS dataset
# gblinear
# {'alpha': 2.2012845190671833, 'lambda': 9.585749777482139, 'learning_rate': 0.06281582374305802, 'num_boost_round': 559.4507945736697, 'objective': 'binary:logistic', 'scale_pos_weight': 6, 'updater': 'shotgun', 'verbosity': 0, 'booster': 'gblinear', 'feature_selector': 'shuffle'}
# [0]	validation_0-auc:0.66634	validation_1-auc:0.61266
# [1]	validation_0-auc:0.68112	validation_1-auc:0.62262
# [2]	validation_0-auc:0.69121	validation_1-auc:0.62837
# [3]	validation_0-auc:0.69830	validation_1-auc:0.63224
# [4]	validation_0-auc:0.70352	validation_1-auc:0.63509
# [5]	validation_0-auc:0.70737	validation_1-auc:0.63726
# [6]	validation_0-auc:0.71045	validation_1-auc:0.63889
# [7]	validation_0-auc:0.71313	validation_1-auc:0.64037
# [8]	validation_0-auc:0.71532	validation_1-auc:0.64202
# [9]	validation_0-auc:0.71727	validation_1-auc:0.64359
# [10]	validation_0-auc:0.71900	validation_1-auc:0.64424
# [11]	validation_0-auc:0.72056	validation_1-auc:0.64508
# [12]	validation_0-auc:0.72198	validation_1-auc:0.64602
# [13]	validation_0-auc:0.72321	validation_1-auc:0.64647
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14]	validation_0-auc:0.72430	validation_1-auc:0.64705
# [15]	validation_0-auc:0.72537	validation_1-auc:0.64740
# [16]	validation_0-auc:0.72625	validation_1-auc:0.64797
# [17]	validation_0-auc:0.72713	validation_1-auc:0.64850
# [18]	validation_0-auc:0.72787	validation_1-auc:0.64870
# [19]	validation_0-auc:0.72854	validation_1-auc:0.64885
# [20]	validation_0-auc:0.72928	validation_1-auc:0.64904
# [21]	validation_0-auc:0.72985	validation_1-auc:0.64926
# [22]	validation_0-auc:0.73038	validation_1-auc:0.64930
# [23]	validation_0-auc:0.73081	validation_1-auc:0.64917
# [24]	validation_0-auc:0.73119	validation_1-auc:0.64933
# [25]	validation_0-auc:0.73163	validation_1-auc:0.64944
# [26]	validation_0-auc:0.73208	validation_1-auc:0.64963
# [27]	validation_0-auc:0.73243	validation_1-auc:0.64973
# [28]	validation_0-auc:0.73288	validation_1-auc:0.64980
# [29]	validation_0-auc:0.73318	validation_1-auc:0.64990
# [30]	validation_0-auc:0.73349	validation_1-auc:0.64998
# [31]	validation_0-auc:0.73382	validation_1-auc:0.64985
# [32]	validation_0-auc:0.73404	validation_1-auc:0.64992
# [33]	validation_0-auc:0.73425	validation_1-auc:0.64982
# [34]	validation_0-auc:0.73451	validation_1-auc:0.64996
# [35]	validation_0-auc:0.73468	validation_1-auc:0.65008
# [36]	validation_0-auc:0.73488	validation_1-auc:0.65020
# [37]	validation_0-auc:0.73509	validation_1-auc:0.65029
# [38]	validation_0-auc:0.73525	validation_1-auc:0.65045
# [39]	validation_0-auc:0.73542	validation_1-auc:0.65050
# [40]	validation_0-auc:0.73558	validation_1-auc:0.65050
# [41]	validation_0-auc:0.73576	validation_1-auc:0.65051
# [42]	validation_0-auc:0.73592	validation_1-auc:0.65046
# [43]	validation_0-auc:0.73603	validation_1-auc:0.65063
# [44]	validation_0-auc:0.73617	validation_1-auc:0.65077
# [45]	validation_0-auc:0.73631	validation_1-auc:0.65093
# [46]	validation_0-auc:0.73640	validation_1-auc:0.65098
# [47]	validation_0-auc:0.73648	validation_1-auc:0.65106
# [48]	validation_0-auc:0.73659	validation_1-auc:0.65116
# [49]	validation_0-auc:0.73670	validation_1-auc:0.65129
# [50]	validation_0-auc:0.73678	validation_1-auc:0.65137
# [51]	validation_0-auc:0.73687	validation_1-auc:0.65141
# [52]	validation_0-auc:0.73702	validation_1-auc:0.65166
# [53]	validation_0-auc:0.73709	validation_1-auc:0.65174
# [54]	validation_0-auc:0.73716	validation_1-auc:0.65178
# [55]	validation_0-auc:0.73726	validation_1-auc:0.65184
# [56]	validation_0-auc:0.73737	validation_1-auc:0.65198
# [57]	validation_0-auc:0.73746	validation_1-auc:0.65186
# [58]	validation_0-auc:0.73754	validation_1-auc:0.65182
# [59]	validation_0-auc:0.73767	validation_1-auc:0.65171
# [60]	validation_0-auc:0.73776	validation_1-auc:0.65158
# [0]	validation_0-auc:0.66409	validation_1-auc:0.60749
# [1]	validation_0-auc:0.67782	validation_1-auc:0.62019
# [2]	validation_0-auc:0.68666	validation_1-auc:0.62830
# [3]	validation_0-auc:0.69386	validation_1-auc:0.63514
# [4]	validation_0-auc:0.69912	validation_1-auc:0.63902
# [5]	validation_0-auc:0.70324	validation_1-auc:0.64236
# [6]	validation_0-auc:0.70689	validation_1-auc:0.64488
# [7]	validation_0-auc:0.70999	validation_1-auc:0.64702
# [8]	validation_0-auc:0.71280	validation_1-auc:0.64816
# [9]	validation_0-auc:0.71499	validation_1-auc:0.64954
# [10]	validation_0-auc:0.71681	validation_1-auc:0.65075
# [11]	validation_0-auc:0.71845	validation_1-auc:0.65178
# [12]	validation_0-auc:0.72004	validation_1-auc:0.65246
# [13]	validation_0-auc:0.72150	validation_1-auc:0.65270
# [14]	validation_0-auc:0.72265	validation_1-auc:0.65334
# [15]	validation_0-auc:0.72375	validation_1-auc:0.65396
# [16]	validation_0-auc:0.72466	validation_1-auc:0.65377
# [17]	validation_0-auc:0.72551	validation_1-auc:0.65414
# [18]	validation_0-auc:0.72635	validation_1-auc:0.65434
# [19]	validation_0-auc:0.72712	validation_1-auc:0.65433
# [20]	validation_0-auc:0.72790	validation_1-auc:0.65441
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21]	validation_0-auc:0.72860	validation_1-auc:0.65397
# [22]	validation_0-auc:0.72924	validation_1-auc:0.65363
# [23]	validation_0-auc:0.72982	validation_1-auc:0.65363
# [24]	validation_0-auc:0.73037	validation_1-auc:0.65353
# [0]	validation_0-auc:0.66328	validation_1-auc:0.64954
# [1]	validation_0-auc:0.67948	validation_1-auc:0.66029
# [2]	validation_0-auc:0.69099	validation_1-auc:0.66798
# [3]	validation_0-auc:0.69903	validation_1-auc:0.67383
# [4]	validation_0-auc:0.70467	validation_1-auc:0.67681
# [5]	validation_0-auc:0.70879	validation_1-auc:0.67843
# [6]	validation_0-auc:0.71235	validation_1-auc:0.67909
# [7]	validation_0-auc:0.71507	validation_1-auc:0.67943
# [8]	validation_0-auc:0.71722	validation_1-auc:0.67978
# [9]	validation_0-auc:0.71906	validation_1-auc:0.68035
# [10]	validation_0-auc:0.72075	validation_1-auc:0.68046
# [11]	validation_0-auc:0.72216	validation_1-auc:0.68005
# [12]	validation_0-auc:0.72340	validation_1-auc:0.68021
# [13]	validation_0-auc:0.72438	validation_1-auc:0.68044
# [14]	validation_0-auc:0.72545	validation_1-auc:0.68039
# [15]	validation_0-auc:0.72628	validation_1-auc:0.68059
# [16]	validation_0-auc:0.72699	validation_1-auc:0.68051
# [17]	validation_0-auc:0.72764	validation_1-auc:0.68007
# [18]	validation_0-auc:0.72823	validation_1-auc:0.67994
# [19]	validation_0-auc:0.72892	validation_1-auc:0.67983
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.67437	validation_1-auc:0.61149
# [1]	validation_0-auc:0.68928	validation_1-auc:0.61647
# [2]	validation_0-auc:0.69946	validation_1-auc:0.61983
# [3]	validation_0-auc:0.70686	validation_1-auc:0.62143
# [4]	validation_0-auc:0.71226	validation_1-auc:0.62248
# [5]	validation_0-auc:0.71656	validation_1-auc:0.62277
# [6]	validation_0-auc:0.72001	validation_1-auc:0.62263
# [7]	validation_0-auc:0.72299	validation_1-auc:0.62245
# [8]	validation_0-auc:0.72559	validation_1-auc:0.62252
# [9]	validation_0-auc:0.72764	validation_1-auc:0.62296
# [10]	validation_0-auc:0.72969	validation_1-auc:0.62205
# [11]	validation_0-auc:0.73134	validation_1-auc:0.62146
# [12]	validation_0-auc:0.73290	validation_1-auc:0.62073
# [13]	validation_0-auc:0.73443	validation_1-auc:0.62034
# [14]	validation_0-auc:0.73575	validation_1-auc:0.61990
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.66878	validation_1-auc:0.66964
# [1]	validation_0-auc:0.68338	validation_1-auc:0.67014
# [2]	validation_0-auc:0.69414	validation_1-auc:0.67184
# [3]	validation_0-auc:0.70075	validation_1-auc:0.67253
# [4]	validation_0-auc:0.70583	validation_1-auc:0.67188
# [5]	validation_0-auc:0.70968	validation_1-auc:0.67180
# [6]	validation_0-auc:0.71288	validation_1-auc:0.67194
# [7]	validation_0-auc:0.71536	validation_1-auc:0.67200
# ########## RESULTS ##########
# {
#     "ROC-AUC Score": [
#         0.5984179577894352,
#         0.00822012021923014
#     ],
#     "F1 Score": [
#         0.2841551013738016,
#         0.007856574006445547
#     ],
#     "Precision": [
#         0.2012667739325828,
#         0.004449152140317233
#     ],
#     "Recall": [
#         0.48342857142857143,
#         0.02216082220533178
#     ],
#     "Balanced Accuracy": [
#         0.5984179577894352,
#         0.00822012021923014
#     ]
# }
#
#
# Evaluating DEC_Feature_DS dataset
# gblinear
# {'alpha': 3.669265694367747e-06, 'lambda': 0.003691484710585189, 'learning_rate': 0.0101804927699945, 'num_boost_round': 600.9232175086469, 'objective': 'binary:logistic', 'scale_pos_weight': 6, 'updater': 'shotgun', 'verbosity': 0, 'booster': 'gblinear', 'feature_selector': 'shuffle'}
# [0]	validation_0-auc:0.66733	validation_1-auc:0.59282
# [1]	validation_0-auc:0.67653	validation_1-auc:0.60047
# [2]	validation_0-auc:0.68396	validation_1-auc:0.60482
# [3]	validation_0-auc:0.69041	validation_1-auc:0.60783
# [4]	validation_0-auc:0.69649	validation_1-auc:0.61182
# [5]	validation_0-auc:0.70211	validation_1-auc:0.61452
# [6]	validation_0-auc:0.70762	validation_1-auc:0.61733
# [7]	validation_0-auc:0.71245	validation_1-auc:0.61940
# [8]	validation_0-auc:0.71697	validation_1-auc:0.62226
# [9]	validation_0-auc:0.72136	validation_1-auc:0.62443
# [10]	validation_0-auc:0.72551	validation_1-auc:0.62679
# [11]	validation_0-auc:0.72938	validation_1-auc:0.62771
# [12]	validation_0-auc:0.73297	validation_1-auc:0.62911
# [13]	validation_0-auc:0.73650	validation_1-auc:0.62991
# [14]	validation_0-auc:0.73976	validation_1-auc:0.63095
# [15]	validation_0-auc:0.74265	validation_1-auc:0.63183
# [16]	validation_0-auc:0.74562	validation_1-auc:0.63289
# [17]	validation_0-auc:0.74849	validation_1-auc:0.63374
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18]	validation_0-auc:0.75105	validation_1-auc:0.63475
# [19]	validation_0-auc:0.75357	validation_1-auc:0.63519
# [20]	validation_0-auc:0.75601	validation_1-auc:0.63548
# [21]	validation_0-auc:0.75816	validation_1-auc:0.63609
# [22]	validation_0-auc:0.76034	validation_1-auc:0.63642
# [23]	validation_0-auc:0.76237	validation_1-auc:0.63718
# [24]	validation_0-auc:0.76444	validation_1-auc:0.63765
# [25]	validation_0-auc:0.76632	validation_1-auc:0.63796
# [26]	validation_0-auc:0.76819	validation_1-auc:0.63839
# [27]	validation_0-auc:0.76996	validation_1-auc:0.63923
# [28]	validation_0-auc:0.77175	validation_1-auc:0.63937
# [29]	validation_0-auc:0.77338	validation_1-auc:0.63943
# [30]	validation_0-auc:0.77498	validation_1-auc:0.64002
# [31]	validation_0-auc:0.77661	validation_1-auc:0.64046
# [32]	validation_0-auc:0.77818	validation_1-auc:0.64088
# [33]	validation_0-auc:0.77956	validation_1-auc:0.64124
# [34]	validation_0-auc:0.78100	validation_1-auc:0.64154
# [35]	validation_0-auc:0.78234	validation_1-auc:0.64141
# [36]	validation_0-auc:0.78367	validation_1-auc:0.64171
# [37]	validation_0-auc:0.78491	validation_1-auc:0.64187
# [38]	validation_0-auc:0.78615	validation_1-auc:0.64184
# [39]	validation_0-auc:0.78735	validation_1-auc:0.64203
# [40]	validation_0-auc:0.78858	validation_1-auc:0.64203
# [41]	validation_0-auc:0.78972	validation_1-auc:0.64233
# [42]	validation_0-auc:0.79080	validation_1-auc:0.64250
# [43]	validation_0-auc:0.79192	validation_1-auc:0.64256
# [44]	validation_0-auc:0.79298	validation_1-auc:0.64258
# [45]	validation_0-auc:0.79395	validation_1-auc:0.64264
# [46]	validation_0-auc:0.79495	validation_1-auc:0.64269
# [47]	validation_0-auc:0.79597	validation_1-auc:0.64248
# [48]	validation_0-auc:0.79692	validation_1-auc:0.64216
# [49]	validation_0-auc:0.79784	validation_1-auc:0.64189
# [50]	validation_0-auc:0.79871	validation_1-auc:0.64179
# [0]	validation_0-auc:0.66254	validation_1-auc:0.61557
# [1]	validation_0-auc:0.67039	validation_1-auc:0.62563
# [2]	validation_0-auc:0.67652	validation_1-auc:0.63056
# [3]	validation_0-auc:0.68274	validation_1-auc:0.63399
# [4]	validation_0-auc:0.68834	validation_1-auc:0.63789
# [5]	validation_0-auc:0.69377	validation_1-auc:0.64108
# [6]	validation_0-auc:0.69927	validation_1-auc:0.64383
# [7]	validation_0-auc:0.70429	validation_1-auc:0.64658
# [8]	validation_0-auc:0.70911	validation_1-auc:0.64863
# [9]	validation_0-auc:0.71378	validation_1-auc:0.65033
# [10]	validation_0-auc:0.71811	validation_1-auc:0.65189
# [11]	validation_0-auc:0.72230	validation_1-auc:0.65347
# [12]	validation_0-auc:0.72629	validation_1-auc:0.65497
# [13]	validation_0-auc:0.73002	validation_1-auc:0.65637
# [14]	validation_0-auc:0.73346	validation_1-auc:0.65754
# [15]	validation_0-auc:0.73686	validation_1-auc:0.65851
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16]	validation_0-auc:0.73999	validation_1-auc:0.65960
# [17]	validation_0-auc:0.74308	validation_1-auc:0.66107
# [18]	validation_0-auc:0.74589	validation_1-auc:0.66178
# [19]	validation_0-auc:0.74853	validation_1-auc:0.66256
# [20]	validation_0-auc:0.75118	validation_1-auc:0.66328
# [21]	validation_0-auc:0.75358	validation_1-auc:0.66412
# [22]	validation_0-auc:0.75583	validation_1-auc:0.66497
# [23]	validation_0-auc:0.75810	validation_1-auc:0.66610
# [24]	validation_0-auc:0.76028	validation_1-auc:0.66694
# [25]	validation_0-auc:0.76225	validation_1-auc:0.66768
# [26]	validation_0-auc:0.76416	validation_1-auc:0.66799
# [27]	validation_0-auc:0.76602	validation_1-auc:0.66828
# [28]	validation_0-auc:0.76773	validation_1-auc:0.66882
# [29]	validation_0-auc:0.76947	validation_1-auc:0.66905
# [30]	validation_0-auc:0.77103	validation_1-auc:0.66954
# [31]	validation_0-auc:0.77252	validation_1-auc:0.66984
# [32]	validation_0-auc:0.77402	validation_1-auc:0.66988
# [33]	validation_0-auc:0.77538	validation_1-auc:0.67004
# [34]	validation_0-auc:0.77680	validation_1-auc:0.67035
# [35]	validation_0-auc:0.77820	validation_1-auc:0.67034
# [36]	validation_0-auc:0.77945	validation_1-auc:0.67046
# [37]	validation_0-auc:0.78067	validation_1-auc:0.67062
# [38]	validation_0-auc:0.78187	validation_1-auc:0.67102
# [39]	validation_0-auc:0.78301	validation_1-auc:0.67092
# [40]	validation_0-auc:0.78408	validation_1-auc:0.67108
# [41]	validation_0-auc:0.78517	validation_1-auc:0.67135
# [42]	validation_0-auc:0.78627	validation_1-auc:0.67145
# [43]	validation_0-auc:0.78731	validation_1-auc:0.67154
# [44]	validation_0-auc:0.78828	validation_1-auc:0.67150
# [45]	validation_0-auc:0.78923	validation_1-auc:0.67160
# [46]	validation_0-auc:0.79012	validation_1-auc:0.67157
# [47]	validation_0-auc:0.79102	validation_1-auc:0.67130
# [48]	validation_0-auc:0.79197	validation_1-auc:0.67131
# [49]	validation_0-auc:0.79284	validation_1-auc:0.67114
# [0]	validation_0-auc:0.66244	validation_1-auc:0.65301
# [1]	validation_0-auc:0.67129	validation_1-auc:0.65617
# [2]	validation_0-auc:0.67860	validation_1-auc:0.65873
# [3]	validation_0-auc:0.68517	validation_1-auc:0.66271
# [4]	validation_0-auc:0.69108	validation_1-auc:0.66527
# [5]	validation_0-auc:0.69708	validation_1-auc:0.66813
# [6]	validation_0-auc:0.70275	validation_1-auc:0.67049
# [7]	validation_0-auc:0.70804	validation_1-auc:0.67335
# [8]	validation_0-auc:0.71302	validation_1-auc:0.67485
# [9]	validation_0-auc:0.71778	validation_1-auc:0.67610
# [10]	validation_0-auc:0.72190	validation_1-auc:0.67815
# [11]	validation_0-auc:0.72601	validation_1-auc:0.67960
# [12]	validation_0-auc:0.72983	validation_1-auc:0.68027
# [13]	validation_0-auc:0.73358	validation_1-auc:0.68128
# [14]	validation_0-auc:0.73707	validation_1-auc:0.68214
# [15]	validation_0-auc:0.74033	validation_1-auc:0.68302
# [16]	validation_0-auc:0.74340	validation_1-auc:0.68405
# [17]	validation_0-auc:0.74630	validation_1-auc:0.68477
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18]	validation_0-auc:0.74898	validation_1-auc:0.68548
# [19]	validation_0-auc:0.75145	validation_1-auc:0.68534
# [20]	validation_0-auc:0.75406	validation_1-auc:0.68595
# [21]	validation_0-auc:0.75631	validation_1-auc:0.68622
# [22]	validation_0-auc:0.75846	validation_1-auc:0.68627
# [23]	validation_0-auc:0.76051	validation_1-auc:0.68639
# [24]	validation_0-auc:0.76244	validation_1-auc:0.68659
# [25]	validation_0-auc:0.76438	validation_1-auc:0.68677
# [26]	validation_0-auc:0.76623	validation_1-auc:0.68716
# [27]	validation_0-auc:0.76806	validation_1-auc:0.68746
# [28]	validation_0-auc:0.76970	validation_1-auc:0.68744
# [29]	validation_0-auc:0.77129	validation_1-auc:0.68733
# [30]	validation_0-auc:0.77267	validation_1-auc:0.68783
# [31]	validation_0-auc:0.77418	validation_1-auc:0.68787
# [32]	validation_0-auc:0.77556	validation_1-auc:0.68756
# [33]	validation_0-auc:0.77692	validation_1-auc:0.68775
# [34]	validation_0-auc:0.77825	validation_1-auc:0.68787
# [35]	validation_0-auc:0.77955	validation_1-auc:0.68779
# [36]	validation_0-auc:0.78076	validation_1-auc:0.68760
# [0]	validation_0-auc:0.66708	validation_1-auc:0.62157
# [1]	validation_0-auc:0.67725	validation_1-auc:0.62541
# [2]	validation_0-auc:0.68372	validation_1-auc:0.62781
# [3]	validation_0-auc:0.69021	validation_1-auc:0.63070
# [4]	validation_0-auc:0.69620	validation_1-auc:0.63299
# [5]	validation_0-auc:0.70197	validation_1-auc:0.63476
# [6]	validation_0-auc:0.70756	validation_1-auc:0.63728
# [7]	validation_0-auc:0.71261	validation_1-auc:0.63854
# [8]	validation_0-auc:0.71738	validation_1-auc:0.64044
# [9]	validation_0-auc:0.72188	validation_1-auc:0.64202
# [10]	validation_0-auc:0.72606	validation_1-auc:0.64318
# [11]	validation_0-auc:0.73006	validation_1-auc:0.64416
# [12]	validation_0-auc:0.73377	validation_1-auc:0.64538
# [13]	validation_0-auc:0.73727	validation_1-auc:0.64708
# [14]	validation_0-auc:0.74056	validation_1-auc:0.64771
# [15]	validation_0-auc:0.74369	validation_1-auc:0.64805
# [16]	validation_0-auc:0.74651	validation_1-auc:0.64860
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17]	validation_0-auc:0.74938	validation_1-auc:0.64950
# [18]	validation_0-auc:0.75189	validation_1-auc:0.64995
# [19]	validation_0-auc:0.75438	validation_1-auc:0.65081
# [20]	validation_0-auc:0.75666	validation_1-auc:0.65150
# [21]	validation_0-auc:0.75884	validation_1-auc:0.65207
# [22]	validation_0-auc:0.76095	validation_1-auc:0.65269
# [23]	validation_0-auc:0.76300	validation_1-auc:0.65305
# [24]	validation_0-auc:0.76492	validation_1-auc:0.65378
# [25]	validation_0-auc:0.76676	validation_1-auc:0.65433
# [26]	validation_0-auc:0.76860	validation_1-auc:0.65480
# [27]	validation_0-auc:0.77025	validation_1-auc:0.65484
# [28]	validation_0-auc:0.77188	validation_1-auc:0.65503
# [29]	validation_0-auc:0.77350	validation_1-auc:0.65526
# [30]	validation_0-auc:0.77511	validation_1-auc:0.65591
# [31]	validation_0-auc:0.77666	validation_1-auc:0.65618
# [32]	validation_0-auc:0.77809	validation_1-auc:0.65644
# [33]	validation_0-auc:0.77941	validation_1-auc:0.65636
# [34]	validation_0-auc:0.78079	validation_1-auc:0.65661
# [35]	validation_0-auc:0.78206	validation_1-auc:0.65703
# [36]	validation_0-auc:0.78331	validation_1-auc:0.65729
# [37]	validation_0-auc:0.78452	validation_1-auc:0.65751
# [38]	validation_0-auc:0.78574	validation_1-auc:0.65748
# [39]	validation_0-auc:0.78679	validation_1-auc:0.65790
# [40]	validation_0-auc:0.78787	validation_1-auc:0.65798
# [41]	validation_0-auc:0.78891	validation_1-auc:0.65792
# [42]	validation_0-auc:0.78997	validation_1-auc:0.65811
# [43]	validation_0-auc:0.79100	validation_1-auc:0.65821
# [44]	validation_0-auc:0.79205	validation_1-auc:0.65842
# [45]	validation_0-auc:0.79305	validation_1-auc:0.65836
# [46]	validation_0-auc:0.79400	validation_1-auc:0.65835
# [47]	validation_0-auc:0.79488	validation_1-auc:0.65844
# [48]	validation_0-auc:0.79577	validation_1-auc:0.65843
# [49]	validation_0-auc:0.79662	validation_1-auc:0.65855
# [50]	validation_0-auc:0.79746	validation_1-auc:0.65862
# [51]	validation_0-auc:0.79828	validation_1-auc:0.65832
# [52]	validation_0-auc:0.79909	validation_1-auc:0.65834
# [53]	validation_0-auc:0.79987	validation_1-auc:0.65839
# [54]	validation_0-auc:0.80063	validation_1-auc:0.65839
# [0]	validation_0-auc:0.66423	validation_1-auc:0.69398
# [1]	validation_0-auc:0.67173	validation_1-auc:0.69234
# [2]	validation_0-auc:0.67839	validation_1-auc:0.69227
# [3]	validation_0-auc:0.68477	validation_1-auc:0.69350
# [4]	validation_0-auc:0.69076	validation_1-auc:0.69417
# [5]	validation_0-auc:0.69639	validation_1-auc:0.69551
# [6]	validation_0-auc:0.70178	validation_1-auc:0.69617
# [7]	validation_0-auc:0.70701	validation_1-auc:0.69705
# [8]	validation_0-auc:0.71184	validation_1-auc:0.69821
# [9]	validation_0-auc:0.71645	validation_1-auc:0.69863
# [10]	validation_0-auc:0.72057	validation_1-auc:0.69913
# [11]	validation_0-auc:0.72468	validation_1-auc:0.69936
# [12]	validation_0-auc:0.72844	validation_1-auc:0.69950
# [13]	validation_0-auc:0.73209	validation_1-auc:0.69973
# [14]	validation_0-auc:0.73556	validation_1-auc:0.69980
# [15]	validation_0-auc:0.73872	validation_1-auc:0.70029
# /Users/Paul/miniforge3/envs/xgboost/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16]	validation_0-auc:0.74183	validation_1-auc:0.70027
# [17]	validation_0-auc:0.74471	validation_1-auc:0.70024
# [18]	validation_0-auc:0.74757	validation_1-auc:0.70029
# [19]	validation_0-auc:0.75014	validation_1-auc:0.70049
# [20]	validation_0-auc:0.75257	validation_1-auc:0.70026
# [21]	validation_0-auc:0.75484	validation_1-auc:0.70010
# [22]	validation_0-auc:0.75705	validation_1-auc:0.69995
# [23]	validation_0-auc:0.75924	validation_1-auc:0.69944
# [24]	validation_0-auc:0.76130	validation_1-auc:0.69894
# ########## RESULTS ##########
# {
#     "ROC-AUC Score": [
#         0.6008881298035866,
#         0.0057405877460224635
#     ],
#     "F1 Score": [
#         0.28724187751687336,
#         0.005800053381732027
#     ],
#     "Precision": [
#         0.20495149900671886,
#         0.0036402269404807145
#     ],
#     "Recall": [
#         0.48,
#         0.013030576286847296
#     ],
#     "Balanced Accuracy": [
#         0.6008881298035866,
#         0.005740587746022455
#     ]
# }
